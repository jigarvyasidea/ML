# %%
import pandas as pd

df = pd.read_csv('ecom.csv')

# %%
df.head()
# Out:
#                                           utterance        intent category  \
# 0       I have a question about cancelling an order  cancel_order    ORDER
# 1              help canceling the order I have made  cancel_order    ORDER
# 2  I do not know how to cancel an order I have made  cancel_order    ORDER
# 3         where can I cancel the last order I made?  cancel_order    ORDER
# 4                I don't want the last order I made  cancel_order    ORDER
#
#   tags
# 0    B
# 1    B
# 2   BE
# 3   BI
# 4    B

# %%
df.isnull()
# Out:
#      utterance  intent  category   tags
# 0        False   False     False  False
# 1        False   False     False  False
# 2        False   False     False  False
# 3        False   False     False  False
# 4        False   False     False  False
# ..         ...     ...       ...    ...
# 813      False   False     False  False
# 814      False   False     False  False
# 815      False   False     False  False
# 816      False   False     False  False
# 817      False   False     False  False
#
# [818 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# utterance    0
# intent       0
# category     0
# tags         0
# dtype: int64

# %%
df['utterance'][0]
# Out:
# 'I have a question about cancelling an order'

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 813    False
# 814    False
# 815    False
# 816    False
# 817    False
# Length: 818, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# in data there 
# no null value
# no duplicated 

# let took it deatisl all the columns

df.sample(20)
# Out:
#                                              utterance  \
# 497  I would like to get the invoice from nine mont...
# 766            how can I check the status of my order?
# 543  information about the company newsletter subsc...
# 435  I would like information about the delivery pe...
# 692  why I cannot set a different shipping address ...
# 606                    I have to buy some of your item
# 92             i want assistance to modify the address
# 51           I want help adding some items to an order
# 244                   I am calling to file a complaint
# 8            I want information about canceling orders
# 609         I don't know how to buy a few of your item
# 345               is it possible to delete my account?
# 800  I want help checking if there is anything new ...
# 248  how to check at what time customer service ava...
# 650    what do i need to do to informof sign-up issues
# 208       I would like to check your money back policy
# ...

# %%
# currently we work with 2 columns latter we deal with all the columns

# %%
df = df.iloc[ : , 0 : 2]

# %%
df
# Out:
#                                             utterance        intent
# 0         I have a question about cancelling an order  cancel_order
# 1                help canceling the order I have made  cancel_order
# 2    I do not know how to cancel an order I have made  cancel_order
# 3           where can I cancel the last order I made?  cancel_order
# 4                  I don't want the last order I made  cancel_order
# ..                                                ...           ...
# 813      I am trying to check the status of my refund  track_refund
# 814                   help checking the refund status  track_refund
# 815                will you show me my refund status?  track_refund
# 816                          help to track the refund  track_refund
# 817                   I am trying to track the refund  track_refund
#
# [818 rows x 2 columns]

# %%
df.rename(columns={'intent': 'query'}, inplace=True)

# %%
df
# Out:
#                                             utterance         query
# 0         I have a question about cancelling an order  cancel_order
# 1                help canceling the order I have made  cancel_order
# 2    I do not know how to cancel an order I have made  cancel_order
# 3           where can I cancel the last order I made?  cancel_order
# 4                  I don't want the last order I made  cancel_order
# ..                                                ...           ...
# 813      I am trying to check the status of my refund  track_refund
# 814                   help checking the refund status  track_refund
# 815                will you show me my refund status?  track_refund
# 816                          help to track the refund  track_refund
# 817                   I am trying to track the refund  track_refund
#
# [818 rows x 2 columns]

# %%
df.rename(columns={'utterance': 'query' , 'query': 'intent'}, inplace=True)

# %%
df
# Out:
#                                                 query        intent
# 0         I have a question about cancelling an order  cancel_order
# 1                help canceling the order I have made  cancel_order
# 2    I do not know how to cancel an order I have made  cancel_order
# 3           where can I cancel the last order I made?  cancel_order
# 4                  I don't want the last order I made  cancel_order
# ..                                                ...           ...
# 813      I am trying to check the status of my refund  track_refund
# 814                   help checking the refund status  track_refund
# 815                will you show me my refund status?  track_refund
# 816                          help to track the refund  track_refund
# 817                   I am trying to track the refund  track_refund
#
# [818 rows x 2 columns]

# %%
#done with solumnet parth look 
# now what i do i will give label to the text
# import label encoder 

from sklearn.preprocessing import LabelEncoder
# create object with the help of that 
le = LabelEncoder()

# now i give label to the intent columns

df['label_intent'] = le.fit_transform(df['intent'])

# %%
df
# Out:
#                                                 query        intent  \
# 0         I have a question about cancelling an order  cancel_order
# 1                help canceling the order I have made  cancel_order
# 2    I do not know how to cancel an order I have made  cancel_order
# 3           where can I cancel the last order I made?  cancel_order
# 4                  I don't want the last order I made  cancel_order
# ..                                                ...           ...
# 813      I am trying to check the status of my refund  track_refund
# 814                   help checking the refund status  track_refund
# 815                will you show me my refund status?  track_refund
# 816                          help to track the refund  track_refund
# 817                   I am trying to track the refund  track_refund
#
#      label_intent
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# ...

# %%
df.sample(12)
# Out:
#                                                  query  \
# 140    help finding the invoices from my last purchase
# 304                    I want help to contact an agent
# 308                                  speak to an agent
# 747  I do not know what to do to switch to another ...
# 787          I want assistance tracking the last order
# 581               help me solving issues with payments
# 778                     I would like to track an order
# 169  will you show me what payment methods you accept?
# 702                my new shipping address isn't valid
# 561           I want help solving issues with payments
# 197              how could I check your refund policy?
# 402        where to check how long the delivery takes?
#
#                       intent  label_intent
# 140            check_invoice             4
# 304      contact_human_agent             9
# 308      contact_human_agent             9
# 747           switch_account            24
# ...

# %%
from sklearn.model_selection import train_test_split

# Assuming X is features and y is target labels
X_train, X_test, y_train, y_test = train_test_split(df['query'], df['label_intent'], test_size=0.2, random_state=42)

# %%
X_train
# Out:
# 773                                         ETA of order
# 451     assistance editing the information on my account
# 338                 i have to create a different account
# 580        can you help me to solve issues with payment?
# 722           how can I set another shipping address up?
#                              ...
# 71              assistance changing the shipping address
# 106    I need  assistance to see the termination penalty
# 270                   I need to contact customer service
# 435    I would like information about the delivery pe...
# 102                 could I change the shipping address?
# Name: query, Length: 654, dtype: object

# %%
X_train.size
# Out:
# 654

# %%
y_test.size
# Out:
# 164

# %%
# we will see train me humne 80% ddata diya h and test me humne 164 mean 20% data diya h 
# overall conslussion 80% data hum train ke liye use karege and 20% data test ke liye

# %%
# step 3 :- ab humnm preprocessignthe text data
# text into lowercase :- Jigar , jigar , jIgar 
# thats why we contet in into dowercase 

# remove pencuation 

# tokenized the text like we diviede text into chunk 

# parterStemmer it for for dtemming or lemmatization 

# !pip install nltk

# %%
import nltk 

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/macmini-100/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/macmini-100/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # now we convert it into lowercase

# %%
df["query"] = df["query"].apply(lambda x: x.lower() if isinstance(x, str) else x)

# %%
df
# Out:
#                                                 query        intent  \
# 0         i have a question about cancelling an order  cancel_order
# 1                help canceling the order i have made  cancel_order
# 2    i do not know how to cancel an order i have made  cancel_order
# 3           where can i cancel the last order i made?  cancel_order
# 4                  i don't want the last order i made  cancel_order
# ..                                                ...           ...
# 813      i am trying to check the status of my refund  track_refund
# 814                   help checking the refund status  track_refund
# 815                will you show me my refund status?  track_refund
# 816                          help to track the refund  track_refund
# 817                   i am trying to track the refund  track_refund
#
#      label_intent
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# ...

# %%
# done to convert into into lovercase 
df['query'] = df['query'].apply(lambda x: str(x) if pd.notnull(x) else '')

# %%
df['query'] = df['query'].fillna('')

# %%
df
# Out:
#                                                 query        intent  \
# 0         i have a question about cancelling an order  cancel_order
# 1                help canceling the order i have made  cancel_order
# 2    i do not know how to cancel an order i have made  cancel_order
# 3           where can i cancel the last order i made?  cancel_order
# 4                  i don't want the last order i made  cancel_order
# ..                                                ...           ...
# 813      i am trying to check the status of my refund  track_refund
# 814                   help checking the refund status  track_refund
# 815                will you show me my refund status?  track_refund
# 816                          help to track the refund  track_refund
# 817                   i am trying to track the refund  track_refund
#
#      label_intent
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# ...

# %%
import string

# Function to preprocess text
def preprocess_text(text):
    # Lowercase and remove punctuation
    text = text.lower().translate(str.maketrans('', '', string.punctuation))
    return text

# Apply preprocessing
df['Processed_Query'] = df['query'].apply(preprocess_text)

print(df[['query', 'Processed_Query']].head())
# Out:
#                             query                Processed_Query
# 0  What is the capital of France?  what is the capital of france
# 1    How to preprocess text data?    how to preprocess text data
# 2      What are stopwords in NLP?      what are stopwords in nlp

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Encode the intents (labels)
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Intent'] = label_encoder.fit_transform(df['Intent'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['Processed_Query'], df['Intent'], test_size=0.2, random_state=42)

# Convert text to TF-IDF features
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Train a Naive Bayes classifier
model = MultinomialNB()
model.fit(X_train_tfidf, y_train)

# Predict on the test set
y_pred = model.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
# Function to predict intent
def predict_intent(query):
    processed_query = preprocess_text(query)
    query_tfidf = vectorizer.transform([processed_query])
    intent_id = model.predict(query_tfidf)[0]
    intent = label_encoder.inverse_transform([intent_id])[0]
    return intent

# Test the model
query = "How want refun on payment??"
predicted_intent = predict_intent(query)
print(f"Predicted Intent: {predicted_intent}")
# Out:
# Predicted Intent: 0
