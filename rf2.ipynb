# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt

import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

# %%
df= pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
# feature and Target decided
x = df.iloc[ : , 0: -1 ]

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
y = df.iloc[ : , -1 ]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size= 0.2 , random_state = 42)

# %%
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 132   42    1   1       120   295    0        1      162      0      0.0
# 202   58    1   0       150   270    0        0      111      1      0.8
# 196   46    1   2       150   231    0        1      147      0      3.6
# 75    55    0   1       135   250    0        0      161      0      1.4
# 176   60    1   0       117   230    1        1      160      1      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 188   50    1   2       140   233    0        1      163      0      0.6
# 71    51    1   2        94   227    0        1      154      1      0.0
# 106   69    1   3       160   234    1        0      131      0      0.1
# 270   46    1   0       120   249    0        0      144      0      0.8
# 102   63    0   1       140   195    0        1      179      0      0.0
#
#      slope  ca  thal
# 132      2   0     2
# 202      2   0     3
# 196      1   0     2
# ...

# %%
x_train.shape
# Out:
# (242, 13)

# %%
x_test.shape
# Out:
# (61, 13)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train , y_train )
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = rf.predict(x_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.8524590163934426

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
gb = GradientBoostingClassifier()
sv = SVC()
lr = LogisticRegression()

# %%
gb.fit(x_train , y_train)
sv.fit(x_train, y_train)
lr.fit(x_train , y_train)
# Out:
# /Volumes/Software/opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# lets find accuracy 
y_pred = gb.predict(x_test)

accuracy_score(y_test , y_pred)
# Out:
# 0.7704918032786885

# %%
y_pred = sv.predict(x_test)

accuracy_score(y_test ,y_pred )
# Out:
# 0.7049180327868853

# %%
y_pred = lr.predict(x_test)

accuracy_score(y_test , y_pred)
# shayad data accha hoga internally
# Out:
# 0.8852459016393442

# %%
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(max_samples=0.91,random_state=42)

# %%
rf1.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_samples=0.91, random_state=42)

# %%
y_pred = rf1.predict(x_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.8524590163934426

# %%
# Ab isko cross validation kartehai then.

from sklearn.model_selection import cross_val_score


rf = RandomForestClassifier(max_samples=0.75,random_state=42)
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9016393442622951

# %% [markdown]
# # GridSeach CV

# %%
# agar grid search me 25 hyper parameter hai humko kaise pta chalege konsa value sahi h 

# Grid Search kya hota hai.

# Top subse pahle ML model me HyperParameter ko tune karne ke liye yse hoti hai . 
# ab hyper paramer vo setting hoti h vo model ko train karne time pe di jati hai 
# eg randomForestClassifier me N_estimator and decision_tree me Max_depth 


# GridSearch kya hota hai 

#ye ek Grid banata hai . 
# jisme hyperparamer ke possible values hote hai .
# and phir yeh sab combination ko try karke best performance waale combination ko choose karta hai 




# let's understaind Girlsearch kaise kaam karta hai 

# 1. parameter Grid : => Sabse Pahle , hum ek grid banate hai jisme different hyperparamer ke value define karte hai 

# 2. model Training :- phir yeh grid ka kar combinaion ko test kartahai aur model ko train karta hia

# %% [markdown]
# # RandomSearchCV

# %%
# number of decisisong tree in random forest 

n_estimators =  [20, 60 , 100, 120 ]

# number of feature to consider at everysplit 

max_feature = [ 0.2 , 0.6 , 1.0 ]

# maximum no of levels in tree

max_depth = [2 , 8, None]


# Number of Samples
max_samples = [ 0.5 , 0.75 , 1.0 ]

# Bootstrup Samples

bootstrap = [True , False ]


# Minimum number required to split a note 

min_samples_split = [2 , 5 ]

# min. no required for each node

min_sample_leaf = [ 1 ,2 ]

# %%
param_grid = {

    'n_estimators' : n_estimators,
    'max_feature': max_feature , 
    'max_depth': max_depth,
    'max_samples': max_samples
    
}

# %%
print(param_grid)
# Out:
# {'n_estimators': [20, 60, 100, 120], 'max_feature': [0.2, 0.6, 1.0], 'max_depth': [2, 8, None], 'max_samples': [0.5, 0.75, 1.0]}

# %%
rf = RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV

rf_grid = GridSearchCV(estimator = rf, 
                       param_grid = param_grid, 
                       cv = 5, 
                       verbose=2, 
                       n_jobs = -1)

# %%
rf_grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Volumes/Software/opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/Volumes/Software/opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Volumes/Software/opt/anaconda3/lib/python3.12/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
rf_grid.best_params_
